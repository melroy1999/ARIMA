# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("1.csv",delimiter=';\t')
data.head()

# data1 = pd.ExcelWriter('Names.xlsx')
# data.to_excel(data1, index = False)
# data1.save()
# Out:
# D:\melro\Anaconda\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#    Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  CPU usage [MHZ]  \
# 0      1376314846          4                     11703.99824     10912.027692
# 1      1376315146          4                     11703.99824     10890.570362
# 2      1376315446          4                     11703.99824     10434.114431
# 3      1376315746          4                     11703.99824     10539.450415
# 4      1376316046          4                     11703.99824     10951.041020
#
#    CPU usage [%]  Memory capacity provisioned [KB]  Memory usage [KB]  \
# 0      93.233333                        67108864.0       6.129274e+06
# 1      93.050000                        67108864.0       6.755624e+06
# 2      89.150000                        67108864.0       8.947846e+06
# 3      90.050000                        67108864.0       1.879048e+07
# 4      93.566667                        67108864.0       9.305761e+06
#
#    Disk read throughput [KB/s]  Disk write throughput [KB/s]  \
# 0                     0.133333                  15981.600000
# 1                     1.333333                  19137.333333
# 2                     2.533333                  19974.933333
# 3                     5.466667                   8791.800000
# 4                     5.400000                  15679.533333
#
#    Network received throughput [KB/s]  Network transmitted throughput [KB/s]
# 0                            0.000000                               2.133333
# 1                            0.000000                               2.600000
# 2                          535.666667                              23.933333
# 3                          349.666667                               5.466667
# 4                            0.000000                               2.066667

# %%
# Out:
#    Timestamp [ms]  CPU cores  CPU capacity provisioned [MHZ]  CPU usage [MHZ]  \
# 0      1376314846          4                     11703.99824     10912.027692
# 1      1376315146          4                     11703.99824     10890.570362
# 2      1376315446          4                     11703.99824     10434.114431
# 3      1376315746          4                     11703.99824     10539.450415
# 4      1376316046          4                     11703.99824     10951.041020
#
#    CPU usage [%]  Memory capacity provisioned [KB]  Memory usage [KB]  \
# 0      93.233333                        67108864.0       6.129274e+06
# 1      93.050000                        67108864.0       6.755624e+06
# 2      89.150000                        67108864.0       8.947846e+06
# 3      90.050000                        67108864.0       1.879048e+07
# 4      93.566667                        67108864.0       9.305761e+06
#
#    Disk read throughput [KB/s]  Disk write throughput [KB/s]  \
# 0                     0.133333                  15981.600000
# 1                     1.333333                  19137.333333
# 2                     2.533333                  19974.933333
# 3                     5.466667                   8791.800000
# 4                     5.400000                  15679.533333
#
#    Network received throughput [KB/s]  Network transmitted throughput [KB/s]
# 0                            0.000000                               2.133333
# 1                            0.000000                               2.600000
# 2                          535.666667                              23.933333
# 3                          349.666667                               5.466667
# 4                            0.000000                               2.066667

# %%
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
f, ax = plt.subplots(figsize=(15, 6))
plt.xticks(rotation='90')
sns.barplot(x=missing_data.index, y=missing_data['Percent'])
plt.xlabel('df_cont', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
missing_data
# Out:
#                                        Total  Percent
# Timestamp [ms]                             0      0.0
# CPU cores                                  0      0.0
# CPU capacity provisioned [MHZ]             0      0.0
# CPU usage [MHZ]                            0      0.0
# CPU usage [%]                              0      0.0
# Memory capacity provisioned [KB]           0      0.0
# Memory usage [KB]                          0      0.0
# Disk read throughput [KB/s]                0      0.0
# Disk write throughput [KB/s]               0      0.0
# Network received throughput [KB/s]         0      0.0
# Network transmitted throughput [KB/s]      0      0.0

# %%
# if(data["CPU cores"]==0):
#     print("False")
for i in data["CPU usage [MHZ]"]:
    if(i<50):
        print(i)
